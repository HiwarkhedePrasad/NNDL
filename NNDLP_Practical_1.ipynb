# %% [markdown]
# <a href="https://colab.research.google.com/github/HiwarkhedePrasad/NNDL/blob/main/NNDLP_Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #imported the Numpy as np

# %%
vector1 = np.array([23,43,12,456,232,12]) #created the vector array
vector2 = np.array([23,4,23,23,345,98])
addition = vector1 + vector2     #addition of the matrix
addition
# Out:
# array([ 46,  47,  35, 479, 577, 110])

# %%
A = np.array([[12,23,34],[72,46,232],[7523,23,234]])            #Created the matrix for the Multiplication
B = np.array([[123,234,1212],[27,34,45],[231,767,45]])

# %%
C = A@B    #Multiplyting both the matrix
C
# Out:
# array([[   9951,   29668,   17109],
#        [  63690,  196356,   99774],
#        [ 980004, 1940642, 9129441]])
